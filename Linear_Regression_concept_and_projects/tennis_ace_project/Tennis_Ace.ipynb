# %%
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.metrics import mean_squared_error
from math import sqrt
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression

# %%
df = pd.read_csv('tennis_stats.csv')

# %%
df.head()
# Out:
#                  Player  Year  FirstServe  FirstServePointsWon  \
# 0           Pedro Sousa  2016        0.88                 0.50
# 1       Roman Safiullin  2017        0.84                 0.62
# 2           Pedro Sousa  2017        0.83                 0.60
# 3   Rogerio Dutra Silva  2010        0.83                 0.64
# 4  Daniel Gimeno-Traver  2017        0.81                 0.54
#
#    FirstServeReturnPointsWon  SecondServePointsWon  \
# 0                       0.38                  0.50
# 1                       0.26                  0.33
# 2                       0.28                  0.53
# 3                       0.34                  0.59
# 4                       0.00                  0.33
#
#    SecondServeReturnPointsWon  Aces  BreakPointsConverted  BreakPointsFaced  \
# 0                        0.39     0                  0.14                 7
# 1                        0.07     7                  0.00                 7
# ...

# %%
df.columns
# Out:
# Index(['Player', 'Year', 'FirstServe', 'FirstServePointsWon',
#        'FirstServeReturnPointsWon', 'SecondServePointsWon',
#        'SecondServeReturnPointsWon', 'Aces', 'BreakPointsConverted',
#        'BreakPointsFaced', 'BreakPointsOpportunities', 'BreakPointsSaved',
#        'DoubleFaults', 'ReturnGamesPlayed', 'ReturnGamesWon',
#        'ReturnPointsWon', 'ServiceGamesPlayed', 'ServiceGamesWon',
#        'TotalPointsWon', 'TotalServicePointsWon', 'Wins', 'Losses', 'Winnings',
#        'Ranking'],
#       dtype='object')

# %% [markdown]
# Plotting different features against different outcomes to find strong relationships:

# %%
plt.scatter(df['BreakPointsOpportunities'], df['Winnings'], alpha=0.4)
plt.show()

# %%
plt.scatter(df['BreakPointsFaced'], df['Winnings'], alpha=0.4)
plt.show()

# %%
plt.scatter(df['ServiceGamesPlayed'], df['Winnings'], alpha=0.4)
plt.show()

# %%
plt.scatter(df['ReturnGamesPlayed'], df['Winnings'], alpha=0.4)
plt.show()

# %%
plt.scatter(df['Aces'], df['Winnings'], alpha=0.4)
plt.show()

# %%
plt.scatter(df['DoubleFaults'], df['Winnings'], alpha=0.4)
plt.show()

# %% [markdown]
# The strongest relationship seems to be between BreakPointsOpportunities and Winnings, ServiceGamesPlayed and Winnings, ReturnGamesPlayed and Winnings.

# %% [markdown]
# # Single feature linear regression models

# %% [markdown]
# ### BreakPointsOpportunities vs. Winnings

# %%
x=df[['BreakPointsOpportunities']]
y=df[['Winnings']]

# %%
x_train, x_test, y_train, y_test = train_test_split(x, y, train_size = 0.8, test_size = 0.2)

# %%
model = LinearRegression()

# %%
model.fit(x_train, y_train)
# Out:
# LinearRegression(copy_X=True, fit_intercept=True, n_jobs=None, normalize=False)

# %%
y_predict = model.predict(x_test)

# %%
print("Train score:")
print(model.score(x_train, y_train))
print("Test score:")
print(model.score(x_test, y_test))
# Out:
# Train score:
# 0.8229599586896913
# Test score:
# 0.7550635628541348

# %%
plt.scatter(y_test, y_predict, alpha = 0.4)
plt.xlabel("Actual total winnings")
plt.ylabel("Predicted total winning")
plt.title("Predicted vs Actual total winnings in USD per year")
plt.show()

# %% [markdown]
# ### BreakPointsFaced vs. Winnings

# %%
x=df[['BreakPointsFaced']]
y=df[['Winnings']]

# %%
x_train, x_test, y_train, y_test = train_test_split(x, y, train_size = 0.8, test_size = 0.2)

# %%
model.fit(x_train, y_train)
# Out:
# LinearRegression(copy_X=True, fit_intercept=True, n_jobs=None, normalize=False)

# %%
y_predict = model.predict(x_test)

# %%
print("Train score:")
print(model.score(x_train, y_train))
print("Test score:")
print(model.score(x_test, y_test))
# Out:
# Train score:
# 0.7683675361437656
# Test score:
# 0.7629183213629284

# %%
plt.scatter(y_test, y_predict, alpha = 0.4)
plt.xlabel("Actual total winnings")
plt.ylabel("Predicted total winning")
plt.title("Predicted vs Actual total winnings in USD per year")
plt.show()

# %% [markdown]
# ### ServiceGamesPlayed vs. Winnings

# %%
x=df[['ServiceGamesPlayed']]
y=df[['Winnings']]

# %%
x_train, x_test, y_train, y_test = train_test_split(x, y, train_size = 0.8, test_size = 0.2)

# %%
model.fit(x_train, y_train)
# Out:
# LinearRegression(copy_X=True, fit_intercept=True, n_jobs=None, normalize=False)

# %%
y_predict = model.predict(x_test)

# %%
print("Train score:")
print(model.score(x_train, y_train))
print("Test score:")
print(model.score(x_test, y_test))
# Out:
# Train score:
# 0.8460908365780881
# Test score:
# 0.7831832623368715

# %%
plt.scatter(y_test, y_predict, alpha = 0.4)
plt.xlabel("Actual total winnings")
plt.ylabel("Predicted total winning")
plt.title("Predicted vs Actual total winnings in USD per year")
plt.show()

# %% [markdown]
# ### ReturnGamesPlayed vs. Winnings

# %%
x=df[['ReturnGamesPlayed']]
y=df[['Winnings']]

# %%
x_train, x_test, y_train, y_test = train_test_split(x, y, train_size = 0.8, test_size = 0.2)

# %%
model.fit(x_train, y_train)
# Out:
# LinearRegression(copy_X=True, fit_intercept=True, n_jobs=None, normalize=False)

# %%
y_predict = model.predict(x_test)

# %%
print("Train score:")
print(model.score(x_train, y_train))
print("Test score:")
print(model.score(x_test, y_test))
# Out:
# Train score:
# 0.8270271242407877
# Test score:
# 0.8557510597081281

# %%
plt.scatter(y_test, y_predict, alpha = 0.4)
plt.xlabel("Actual total winnings")
plt.ylabel("Predicted total winning")
plt.title("Predicted vs Actual total winnings in USD per year")
plt.show()

# %% [markdown]
# ### Aces vs. Winnings

# %%
x=df[['Aces']]
y=df[['Winnings']]

# %%
x_train, x_test, y_train, y_test = train_test_split(x, y, train_size = 0.8, test_size = 0.2)

# %%
model.fit(x_train, y_train)
# Out:
# LinearRegression(copy_X=True, fit_intercept=True, n_jobs=None, normalize=False)

# %%
y_predict = model.predict(x_test)

# %%
print("Train score:")
print(model.score(x_train, y_train))
print("Test score:")
print(model.score(x_test, y_test))
# Out:
# Train score:
# 0.6333752560758107
# Test score:
# 0.6542013659984149

# %%
plt.scatter(y_test, y_predict, alpha = 0.4)
plt.xlabel("Actual total winnings")
plt.ylabel("Predicted total winning")
plt.title("Predicted vs Actual total winnings in USD per year")
plt.show()

# %% [markdown]
# ### DoubleFaults vs. Winnings

# %%
x=df[['DoubleFaults']]
y=df[['Winnings']]

# %%
x_train, x_test, y_train, y_test = train_test_split(x, y, train_size = 0.8, test_size = 0.2)

# %%
model.fit(x_train, y_train)
# Out:
# LinearRegression(copy_X=True, fit_intercept=True, n_jobs=None, normalize=False)

# %%
y_predict = model.predict(x_test)

# %%
print("Train score:")
print(model.score(x_train, y_train))
print("Test score:")
print(model.score(x_test, y_test))
# Out:
# Train score:
# 0.7317663127065412
# Test score:
# 0.7231290610048817

# %%
plt.scatter(y_test, y_predict, alpha = 0.4)
plt.xlabel("Actual total winnings")
plt.ylabel("Predicted total winning")
plt.title("Predicted vs Actual total winnings in USD per year")
plt.show()

# %% [markdown]
# The most accurate prediction (the highest coefficients of determination for both train and test sets) was obtained in the models with the following features: BreakPointsOpportunities, BreakPointsFaced, ServiceGamesPlayed, ReturnGamesPlayed

# %% [markdown]
# # Two features linear regression models

# %% [markdown]
# ### BreakPointsOpportunities & BreakPointsFaced vs. Winnings

# %%
x=df[['BreakPointsOpportunities', 'BreakPointsFaced']]
y=df[['Winnings']]

# %%
x_train, x_test, y_train, y_test = train_test_split(x, y, train_size = 0.8, test_size = 0.2)

# %%
model.fit(x_train, y_train)
# Out:
# LinearRegression(copy_X=True, fit_intercept=True, n_jobs=None, normalize=False)

# %%
y_predict = model.predict(x_test)

# %%
print("Train score:")
print(model.score(x_train, y_train))
print("Test score:")
print(model.score(x_test, y_test))
# Out:
# Train score:
# 0.8114452738388397
# Test score:
# 0.8048378135513519

# %%
plt.scatter(y_test, y_predict, alpha = 0.4)
plt.xlabel("Actual total winnings")
plt.ylabel("Predicted total winning")
plt.title("Predicted vs Actual total winnings in USD per year")
plt.show()

# %% [markdown]
# ### ServiceGamesPlayed & ReturnGamesPlayed vs. Winnings

# %%
x=df[['ServiceGamesPlayed', 'ReturnGamesPlayed']]
y=df[['Winnings']]

# %%
x_train, x_test, y_train, y_test = train_test_split(x, y, train_size = 0.8, test_size = 0.2)

# %%
model.fit(x_train, y_train)
# Out:
# LinearRegression(copy_X=True, fit_intercept=True, n_jobs=None, normalize=False)

# %%
y_predict = model.predict(x_test)

# %%
print("Train score:")
print(model.score(x_train, y_train))
print("Test score:")
print(model.score(x_test, y_test))
# Out:
# Train score:
# 0.8317119084083744
# Test score:
# 0.8404081415993901

# %%
plt.scatter(y_test, y_predict, alpha = 0.4)
plt.xlabel("Actual total winnings")
plt.ylabel("Predicted total winning")
plt.title("Predicted vs Actual total winnings in USD per year")
plt.show()

# %% [markdown]
# ### BreakPointsOpportunities & ServiceGamesPlayed vs. Winnings

# %%
x=df[['BreakPointsOpportunities', 'ServiceGamesPlayed']]
y=df[['Winnings']]

# %%
x_train, x_test, y_train, y_test = train_test_split(x, y, train_size = 0.8, test_size = 0.2)

# %%
model.fit(x_train, y_train)
# Out:
# LinearRegression(copy_X=True, fit_intercept=True, n_jobs=None, normalize=False)

# %%
y_predict = model.predict(x_test)

# %%
print("Train score:")
print(model.score(x_train, y_train))
print("Test score:")
print(model.score(x_test, y_test))
# Out:
# Train score:
# 0.8289220216499941
# Test score:
# 0.8551295260547677

# %%
plt.scatter(y_test, y_predict, alpha = 0.4)
plt.xlabel("Actual total winnings")
plt.ylabel("Predicted total winning")
plt.title("Predicted vs Actual total winnings in USD per year")
plt.show()

# %% [markdown]
# ### BreakPointsFaced & ReturnGamesPlayed vs. Winnings¶

# %%
x=df[['BreakPointsFaced', 'ReturnGamesPlayed']]
y=df[['Winnings']]

# %%
x_train, x_test, y_train, y_test = train_test_split(x, y, train_size = 0.8, test_size = 0.2)

# %%
model.fit(x_train, y_train)
# Out:
# LinearRegression(copy_X=True, fit_intercept=True, n_jobs=None, normalize=False)

# %%
y_predict = model.predict(x_test)

# %%
print("Train score:")
print(model.score(x_train, y_train))
print("Test score:")
print(model.score(x_test, y_test))
# Out:
# Train score:
# 0.8426296038435426
# Test score:
# 0.805113961907099

# %%
plt.scatter(y_test, y_predict, alpha = 0.4)
plt.xlabel("Actual total winnings")
plt.ylabel("Predicted total winning")
plt.title("Predicted vs Actual total winnings in USD per year")
plt.show()

# %% [markdown]
# The most accurate prediction was obtained in the model with the features BreakPointsOpportunities and ServiceGamesPlayed.

# %% [markdown]
# # Multiple linear regression models

# %% [markdown]
# ### BreakPointsOpportunities & BreakPointsFaced & ServiceGamesPlayed & ReturnGamesPlayed vs. Winnings

# %%
x=df[['BreakPointsOpportunities', 'BreakPointsFaced', 'ServiceGamesPlayed', 'ReturnGamesPlayed']]
y=df[['Winnings']]

# %%
x_train, x_test, y_train, y_test = train_test_split(x, y, train_size = 0.8, test_size = 0.2)

# %%
model.fit(x_train, y_train)
# Out:
# LinearRegression(copy_X=True, fit_intercept=True, n_jobs=None, normalize=False)

# %%
y_predict = model.predict(x_test)

# %%
print("Train score:")
print(model.score(x_train, y_train))
print("Test score:")
print(model.score(x_test, y_test))
# Out:
# Train score:
# 0.8470581907804003
# Test score:
# 0.8091786438659813

# %%
plt.scatter(y_test, y_predict, alpha = 0.4)
plt.xlabel("Actual total winnings")
plt.ylabel("Predicted total winning")
plt.title("Predicted vs Actual total winnings in USD per year")
plt.show()

# %% [markdown]
# ### BreakPointsOpportunities & BreakPointsFaced & ServiceGamesPlayed & ReturnGamesPlayed & Aces & DoubleFaults vs. Winnings

# %%
x=df[['BreakPointsOpportunities', 'BreakPointsFaced', 'ServiceGamesPlayed', 'ReturnGamesPlayed', 'Aces', 'DoubleFaults']]
y=df[['Winnings']]

# %%
x_train, x_test, y_train, y_test = train_test_split(x, y, train_size = 0.8, test_size = 0.2)

# %%
model.fit(x_train, y_train)
# Out:
# LinearRegression(copy_X=True, fit_intercept=True, n_jobs=None, normalize=False)

# %%
y_predict = model.predict(x_test)

# %%
print("Train score:")
print(model.score(x_train, y_train))
print("Test score:")
print(model.score(x_test, y_test))
# Out:
# Train score:
# 0.8466799476562399
# Test score:
# 0.8189026466707167

# %%
plt.scatter(y_test, y_predict, alpha = 0.4)
plt.xlabel("Actual total winnings")
plt.ylabel("Predicted total winning")
plt.title("Predicted vs Actual total winnings in USD per year")
plt.show()

# %% [markdown]
# ### BreakPointsFaced & ServiceGamesPlayed & ReturnGamesPlayed & Aces & DoubleFaults vs. Winnings

# %%
x=df[['BreakPointsFaced', 'ServiceGamesPlayed', 'ReturnGamesPlayed', 'Aces', 'DoubleFaults']]
y=df[['Winnings']]

# %%
x_train, x_test, y_train, y_test = train_test_split(x, y, train_size = 0.8, test_size = 0.2)

# %%
model.fit(x_train, y_train)
# Out:
# LinearRegression(copy_X=True, fit_intercept=True, n_jobs=None, normalize=False)

# %%
y_predict = model.predict(x_test)

# %%
print("Train score:")
print(model.score(x_train, y_train))
print("Test score:")
print(model.score(x_test, y_test))
# Out:
# Train score:
# 0.8437495859029422
# Test score:
# 0.8132375366807927

# %%
plt.scatter(y_test, y_predict, alpha = 0.4)
plt.xlabel("Actual total winnings")
plt.ylabel("Predicted total winning")
plt.title("Predicted vs Actual total winnings in USD per year")
plt.show()

# %% [markdown]
# The most accurate prediction (with the highest R squared for both train and test sets) was obtained in the models with the following features: BreakPointsOpportunities, BreakPointsFaced, ServiceGamesPlayed, ReturnGamesPlayed, Aces, DoubleFaults.
# Hence these 6 features are most important for being a successful tennis player.
